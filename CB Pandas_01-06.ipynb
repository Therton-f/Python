# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Therton_F\Downloads\DA\Python\CB\Flavors.csv")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['EST'][df['Events']=='Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %% [markdown]
# *  in avg it doesnot count the rows with Nan values so avg is high.
# *  1st replace nan with 0 then calculate avg

# %%
df.fillna(0, inplace=True)
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %%
#if want data from dictionary
#df = pd.DataFrame(dict_name)

# %%
df2 = pd.read_csv(r"C:\Users\Therton_F\Downloads\DA\Python\CB\weather_data.csv")
df2
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df2.shape
# Out:
# (6, 4)

# %%
#can save as tuple
rows, column = df2.shape
print(rows)
print(column)
# Out:
# 6
# 4

# %%
df2.head(2)
#head and tail 1st and last 5 rows by default
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny

# %%
df2[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
df2.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df2.day #alternate df2['day']
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
type(df2.event)
# Out:
# pandas.core.series.Series

# %%
df2[['day','event']] #choosing ore than 1 column
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017   Snow
# 4  1/5/2017   Rain
# 5  1/6/2017  Sunny

# %%
df2.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df2[df2.temperature>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
df2[['day','temperature']][df2.temperature==df2.temperature.max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df2.set_index('day', inplace=True)

# %%
df2
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df2.reset_index(inplace=True)
df2
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df3 = pd.read_csv(r"C:\Users\Therton_F\Downloads\DA\Python\CB\weather_data (1).csv")
df3
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
weather_data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]

df3=pd.DataFrame(weather_data, columns=["day","temperature","windspeed","event"])
df3

# if we give data with dictionary then it already contains keys name as column, but with tuples we have to give column name
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df4 = pd.read_csv(r"C:\Users\Therton_F\Downloads\DA\Python\CB\stock_data.csv")
df4
#1st row contain blank values
# Out:
#   stock data     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0    tickers            eps    revenue      price         people
# 1      GOOGL          27.82         87        845     larry page
# 2        WMT           4.61        484         65           n.a.
# 3       MSFT             -1         85         64     bill gates
# 4       RIL   not available         50       1023  mukesh ambani
# 5       TATA            5.6         -1       n.a.     ratan tata

# %%
df4 = pd.read_csv(r"C:\Users\Therton_F\Downloads\DA\Python\CB\stock_data.csv", skiprows=1)
df4
#alternate header=1 also works, bcz index start from 0 so 1 is 2nd line in csv file
#if csv file name dont have column name use (........header=None, names=["ticker","eps","revenue","price","people"]
#if you want read fix no of rows (.......nrows=3)
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df4 = pd.read_csv(r"C:\Users\Therton_F\Downloads\DA\Python\CB\stock_data.csv", skiprows=1, na_values=["not available","n.a."])
df4
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
df4 = pd.read_csv(r"C:\Users\Therton_F\Downloads\DA\Python\CB\stock_data.csv", skiprows=1,
                  na_values={'eps':["not available","n.a."],'revenue':["not available","n.a.",-1]})
df4
#here we have mention column name for which we want NaN values, in revenue column we want -1 also to be NaN
#and you have to mention every column that you want to clean
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65           n.a.
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
df4.to_csv(r"C:\Users\Therton_F\Downloads\DA\Python\CB\new.csv", index=False)
#creating csv w/o creating index column

# %%
df4.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
#exporting only specific columns
df4.to_csv(r"C:\Users\Therton_F\Downloads\DA\Python\CB\new.csv", columns=['tickers', 'eps'])

# %%
#exporting w/o header
df4.to_csv(r"C:\Users\Therton_F\Downloads\DA\Python\CB\new.csv", header=False)

# %%
df5 = pd.read_excel(r"C:\Users\Therton_F\Downloads\DA\Python\CB\stock_data.xlsx")
df5
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
def convert_people_cell(cell):
  if cell == "n.a.":
    return 'sam walton'
  return cell

def convert_eps_cell(cell):
  if cell == "not available":
    return None
  return cell

df5 = pd.read_excel(r"C:\Users\Therton_F\Downloads\DA\Python\CB\stock_data.xlsx",
                    converters ={'people': convert_people_cell,
                                 'eps' : convert_eps_cell
                                 })
df5
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82       87   845     larry page
# 1     WMT   4.61      484    65     sam walton
# 2    MSFT  -1.00       85    64     bill gates
# 3    RIL     NaN       50  1023  mukesh ambani
# 4    TATA   5.60       -1  n.a.     ratan tata

# %%
df5.to_excel(r"C:\Users\Therton_F\Downloads\DA\Python\CB\new.xlsx", sheet_name='stocks', startrow=1,startcol=2)

# %%
# when you want to as two diff data in same excel file but in different sheet
#      with pd.ExcelWriter("excel file name") as writer:
#         df_stocks.to_excel(writer, sheet_name="stocks")
#         df_weather.to_excel(writer, sheet_name="weather")

# %%
p5 = pd.read_csv(r"C:\Users\Therton_F\Downloads\DA\Python\CB\weather_data (5).csv", parse_dates=["day"])
p5
#converting day column to date format from string format
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
type(p5.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
p5.set_index('day', inplace=True)
p5
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_p5 = p5.fillna(0)
new_p5
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#passind dictionry within fillna to be specific with each column
new_p5 = p5.fillna({
                    'temperature': 0,    
                    'windspeed' : 0,
                    'event' : 'no event'
                    })
new_p5
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  no event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  no event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
new_p5 = p5.fillna(method="ffill")
new_p5
# Out:
# C:\Users\Therton_F\AppData\Local\Temp\ipykernel_6744\60975068.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_p5 = p5.fillna(method="ffill")
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_p5 =p5.bfill()  #or use p5.ffill() bcz method is going tobe removed soon
new_p5
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         34.0        8.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
#before it was taking backward values from next row, now it will take values fro backward column
new_p5 = p5.bfill(axis='columns')
new_p5
# Out:
#            temperature windspeed   event
# day
# 2017-01-01        32.0       6.0    Rain
# 2017-01-04         9.0       9.0   Sunny
# 2017-01-05        28.0      Snow    Snow
# 2017-01-06         7.0       7.0     NaN
# 2017-01-07        32.0      Rain    Rain
# 2017-01-08       Sunny     Sunny   Sunny
# 2017-01-09         NaN       NaN     NaN
# 2017-01-10        34.0       8.0  Cloudy
# 2017-01-11        40.0      12.0   Sunny

# %%
#it will fill only 1 row next, carry forward/backward value once only
new_p5 = p5.ffill(limit=1)
new_p5
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        NaN   Sunny
# 2017-01-09          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
p5.infer_objects(copy=False)

new_p5 = p5.interpolate() #by default linear interpolation
new_p5
# Out:
# C:\Users\Therton_F\AppData\Local\Temp\ipykernel_6744\709656996.py:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_p5 = p5.interpolate()
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
p5.infer_objects(copy=False)
new_p5 = p5.interpolate(method='time') #linear interpolation but keeping in mind the time
new_p5
# Out:
# C:\Users\Therton_F\AppData\Local\Temp\ipykernel_6744\3940808419.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_p5 = p5.interpolate(method='time')
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
new_p5 = p5.dropna()
new_p5
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_p5 = p5.dropna(how="all")
new_p5
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
dt = pd.date_range("01-01-2017","01-11-2017")
idx = pd.DatetimeIndex(dt)
p5 = p5.reindex(idx)
p5
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
p6 = pd.read_csv(r"C:\Users\Therton_F\Downloads\DA\Python\CB\weather_data (2).csv")
p6
# Out:
#           day  temperature  windspeed     event
# 0  01-01-2017           32          6      Rain
# 1  01-02-2017       -99999          7     Sunny
# 2  01-03-2017           28     -99999      Snow
# 3  01-04-2017       -99999          7  no event
# 4  01-05-2017           32     -88888      Rain
# 5  01-06-2017           31          2     Sunny
# 6  01-06-2017           34          5  no event

# %%
new_p6 = p6.replace(-99999, np.NaN)
new_p6
# Out:
#           day  temperature  windspeed     event
# 0  01-01-2017         32.0        6.0      Rain
# 1  01-02-2017          NaN        7.0     Sunny
# 2  01-03-2017         28.0        NaN      Snow
# 3  01-04-2017          NaN        7.0  no event
# 4  01-05-2017         32.0   -88888.0      Rain
# 5  01-06-2017         31.0        2.0     Sunny
# 6  01-06-2017         34.0        5.0  no event

# %%
new_p6 = p6.replace([-99999,-88888], np.NaN)
new_p6
# Out:
#           day  temperature  windspeed     event
# 0  01-01-2017         32.0        6.0      Rain
# 1  01-02-2017          NaN        7.0     Sunny
# 2  01-03-2017         28.0        NaN      Snow
# 3  01-04-2017          NaN        7.0  no event
# 4  01-05-2017         32.0        NaN      Rain
# 5  01-06-2017         31.0        2.0     Sunny
# 6  01-06-2017         34.0        5.0  no event

# %%
new_p6 = p6.replace({
                        'temperature':-99999, 
                        'windspeed':[-99999,-88888],
                        'event':'no event'
                    }, np.NaN)
new_p6
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017          NaN        7.0  Sunny
# 2  01-03-2017         28.0        NaN   Snow
# 3  01-04-2017          NaN        7.0    NaN
# 4  01-05-2017         32.0        NaN   Rain
# 5  01-06-2017         31.0        2.0  Sunny
# 6  01-06-2017         34.0        5.0    NaN

# %%
new_p6 = p6.replace({
                -99999:np.NaN,
                -88888:np.NaN,
                'no event': 'Sunny'
                    })
new_p6
# Out:
#           day  temperature  windspeed  event
# 0  01-01-2017         32.0        6.0   Rain
# 1  01-02-2017          NaN        7.0  Sunny
# 2  01-03-2017         28.0        NaN   Snow
# 3  01-04-2017          NaN        7.0  Sunny
# 4  01-05-2017         32.0        NaN   Rain
# 5  01-06-2017         31.0        2.0  Sunny
# 6  01-06-2017         34.0        5.0  Sunny

# %%
p62 = pd.read_csv(r"C:\Users\Therton_F\Downloads\DA\Python\CB\weather_data (2) - Copy.csv")
p62
# Out:
#           day temperature windspeed     event
# 0  01-01-2017        32 F     6 mph      Rain
# 1  01-02-2017      -99999     7 mph     Sunny
# 2  01-03-2017          28    -99999      Snow
# 3  01-04-2017      -99999         7  no event
# 4  01-05-2017        32 C    -88888      Rain
# 5  01-06-2017          31         2     Sunny
# 6  01-06-2017          34         5  no event

# %%
#regex reove capital A-Z and small a-z from whole data
new_p62 = p62.replace('[A-Za-z]','',regex=True)
new_p62
# Out:
#           day temperature windspeed event
# 0  01-01-2017         32         6
# 1  01-02-2017      -99999        7
# 2  01-03-2017          28    -99999
# 3  01-04-2017      -99999         7
# 4  01-05-2017         32     -88888
# 5  01-06-2017          31         2
# 6  01-06-2017          34         5

# %%
new_p62 = p62.replace({
                        'temperature':'[A-Za-z]',
                        'windspeed' : '[A-Za-z]'
                        },'',regex=True)
new_p62
# Out:
#           day temperature windspeed     event
# 0  01-01-2017         32         6       Rain
# 1  01-02-2017      -99999        7      Sunny
# 2  01-03-2017          28    -99999      Snow
# 3  01-04-2017      -99999         7  no event
# 4  01-05-2017         32     -88888      Rain
# 5  01-06-2017          31         2     Sunny
# 6  01-06-2017          34         5  no event

# %%
p63 = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})
p63
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
# replaceing values of list with another list
new_p63 = p63.replace(['poor', 'average', 'good', 'exceptional'], [1,2,3,4])
new_p63
# Out:
#    score  student
# 0      4      rob
# 1      2     maya
# 2      3  parthiv
# 3      1      tom
# 4      2   julian
# 5      4    erica
